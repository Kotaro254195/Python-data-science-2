# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
x=np.linspace(0,5,11)

y=x**2

x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.show()

# %%
from matplotlib import style

# %%
randomNumber=np.random.rand(10)
randomNumber
# Out:
# array([0.24872161, 0.07963469, 0.80872453, 0.0216779 , 0.16575044,
#        0.06602245, 0.2189787 , 0.04460141, 0.05853907, 0.9736341 ])

# %%
style.use('ggplot')
# 'g' is color.
plt.plot(randomNumber,'g',label='first one', linewidth=2)
plt.xlabel('Range')
plt.ylabel('Number')
plt.title('first Plot')
plt.legend()
plt.show()

# %%
plt.plot(x,y,'r')
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %% [markdown]
# ### Creating Multiplots on Same Canvas

# %%
#plt.subplot(nrows,ncols,number of plot)
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %% [markdown]
# ### pbject oreinted Method

# %%
#create the figure (empty canvas)

fig=plt.figure()

#add set of axess to figures
axes=fig.add_axes([0.1,0.1,0.8,0.8]) #left, bottom, width height (range 0 to 1)

#plot on that set of axes
axes.plot(x,y,'b')

axes.set_xlabel("set X -Label")
axes.set_ylabel("set Y -Label")
axes.set_title("Set Title")
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
# create blank canvas

fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

#larger figure Axes

#Insert Figure Axes1
axes1.plot(x,y,'b')

axes1.set_xlabel('First Plot')
axes1.set_ylabel('Y-axes')
axes1.set_title('Biggerr')

#Insert Figure Axes2
axes2.plot(x,y,'r')

axes2.set_xlabel('X_lavel_axes2')
axes2.set_ylabel('Y_lavel_axes2')
axes2.set_title('Axes 2 Title')
# Out:
# Text(0.5, 1.0, 'Axes 2 Title')

# %% [markdown]
# #### subplots()
# The plt.subplots() object will act as a more automatic axis manager.
# Basic use cases:

# %%
fig, axes=plt.subplots()
#now use the axes objects to add stuff to plot

axes.plot(x,y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
#we have to specify the number of rows and columns when creating the subplots() object

# %%
#empty canvas of 1 by 2 subplots

#1×2のグラフを作る
fig,axes=plt.subplots(nrows=1,ncols=2)

# %%
axes
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000193C4B1F5C0>,
# ...
#        dtype=object))

# %% [markdown]
# ### We can iterate through this array

# %%
for ax in axes:
    ax.plot(x,y, 'b')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('Kotaro')
#display the figure object
fig

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
for ax in axes:
    ax.plot(x,y, 'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
fig
plt.tight_layout()

# %% [markdown]
# # Figure Size, Aspect Ratio and DPI

# %% [markdown]
# #### for example

# %%
fig=plt.figure(figsize=(4,4),dpi=100)

# %%
fig,axes=plt.subplots(figsize=(12,5))
axes.plot(x,y,'y')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
#save this graphs

# %%
fig.savefig('graph_from_jupyter.jpg')

# %%
fig.savefig('graph_from_jupyter',dpi=200)

# %%
#lots of optinos

# ax.legend(loc=1)
# ax.legend(loc=2)
# ax.legend(loc=3)
# ax.legend(loc=4)

#.. many more options are available

#Most common to choose
ax.legend(loc=0)
fig
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Colors with MatLab like syntax

# %%
fig, ax=plt.subplots()

ax.plot(x,x+1,color="blue", alpha=0.1)
ax.plot(x,x+2,color="#880088")
ax.plot(x,x+3,color="#FF8C00")

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)
# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')
# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...
# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')
# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
